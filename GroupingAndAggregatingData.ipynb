# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_columns', 85)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/BakerJr1904/GroupingAndAggregatingData/main/survey_results_public.csv")

# %%
schema_df = pd.read_csv("https://raw.githubusercontent.com/BakerJr1904/GroupingAndAggregatingData/main/survey_results_schema.csv")

# %%
print(df.shape)
df.head()
# Out:
# (51392, 154)
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
schema_df.head()
# Out:
#          Column                                           Question
# 0    Respondent                               Respondent ID number
# 1  Professional         Which of the following best describes you?
# 2  ProgramHobby  Do you program as a hobby or contribute to ope...
# 3       Country            In which country do you currently live?
# 4    University  Are you currently enrolled in a formal, degree...

# %%
schema_df.tail()
# Out:
#                    Column                                           Question
# 149  QuestionsInteresting                     The questions were interesting
# 150    QuestionsConfusing                       The questions were confusing
# 151     InterestedAnswers  I'm interested in learning how other developer...
# 152                Salary  What is your current annual base salary, befor...
# 153        ExpectedSalary  You said before that you are currently learnin...

# %%
df['Salary'].head()
# Out:
# 0         NaN
# 1         NaN
# 2    113750.0
# 3         NaN
# 4         NaN
# Name: Salary, dtype: float64

# %%
df['Salary'].median()
# Out:
# 50000.0

# %%
df.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Respondent                   25696.500000
# CareerSatisfaction               8.000000
# JobSatisfaction                  7.000000
# HoursPerWeek                     1.000000
# StackOverflowSatisfaction        9.000000
# Salary                       50000.000000
# ExpectedSalary               29364.263691
# dtype: float64

# %%
df.describe()
# Out:
#          Respondent  CareerSatisfaction  JobSatisfaction  HoursPerWeek  \
# count  51392.000000        42695.000000     40376.000000  20600.000000
# mean   25696.500000            7.300574         6.957078      3.952282
# std    14835.736854            1.955444         2.167652      7.564722
# min        1.000000            0.000000         0.000000      0.000000
# 25%    12848.750000            6.000000         6.000000      1.000000
# 50%    25696.500000            8.000000         7.000000      1.000000
# 75%    38544.250000            9.000000         8.000000      4.000000
# max    51392.000000           10.000000        10.000000     40.000000
#
#        StackOverflowSatisfaction         Salary  ExpectedSalary
# count               36592.000000   12891.000000     2566.000000
# mean                    8.429875   56298.480641    33142.220468
# std                     1.390635   39880.905277    30162.988829
# min                     0.000000       0.000000        0.000000
# ...

# %%
df['HoursPerWeek'].describe()
# Out:
# count    20600.000000
# mean         3.952282
# std          7.564722
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          4.000000
# max         40.000000
# Name: HoursPerWeek, dtype: float64

# %%
df['Salary'].count()
# Out:
# 12891

# %%
df['YearsProgram']
# Out:
# 0            2 to 3 years
# 1           9 to 10 years
# 2        20 or more years
# 3          14 to 15 years
# 4        20 or more years
#                ...
# 51387        6 to 7 years
# 51388        2 to 3 years
# 51389    Less than a year
# 51390      17 to 18 years
# 51391      14 to 15 years
# Name: YearsProgram, Length: 51392, dtype: object

# %%
df['YearsProgram'].value_counts()
# Out:
# 20 or more years    8817
# 4 to 5 years        3865
# 3 to 4 years        3701
# 5 to 6 years        3572
# 2 to 3 years        3251
# 9 to 10 years       3197
# 6 to 7 years        2869
# 1 to 2 years        2773
# 7 to 8 years        2466
# 10 to 11 years      2178
# 14 to 15 years      2011
# 8 to 9 years        1910
# 15 to 16 years      1669
# Less than a year    1484
# 11 to 12 years      1389
# 12 to 13 years      1307
# 13 to 14 years      1092
# 16 to 17 years      1046
# 19 to 20 years      1021
# 17 to 18 years       879
# 18 to 19 years       648
# Name: YearsProgram, dtype: int64

# %%
df['StackOverflowSatisfaction'].value_counts()
# Out:
# 8.0     10227
# 9.0      9792
# 10.0     9166
# 7.0      4724
# 6.0      1456
# 5.0       716
# 4.0       202
# 3.0       162
# 2.0        73
# 1.0        38
# 0.0        36
# Name: StackOverflowSatisfaction, dtype: int64

# %%
schema_df.head()
# Out:
#          Column                                           Question
# 0    Respondent                               Respondent ID number
# 1  Professional         Which of the following best describes you?
# 2  ProgramHobby  Do you program as a hobby or contribute to ope...
# 3       Country            In which country do you currently live?
# 4    University  Are you currently enrolled in a formal, degree...

# %%
schema_df.loc[61:61]
# Out:
#                 Column                                           Question
# 61  AssessJobDiversity  When you're assessing potential jobs to apply ...

# %%
df['StackOverflowSatisfaction'].value_counts(normalize=True)
# Out:
# 8.0     0.279487
# 9.0     0.267599
# 10.0    0.250492
# 7.0     0.129099
# 6.0     0.039790
# 5.0     0.019567
# 4.0     0.005520
# 3.0     0.004427
# 2.0     0.001995
# 1.0     0.001038
# 0.0     0.000984
# Name: StackOverflowSatisfaction, dtype: float64

# %%
df['Country']
# Out:
# 0         United States
# 1        United Kingdom
# 2        United Kingdom
# 3         United States
# 4           Switzerland
#               ...
# 51387     United States
# 51388         Venezuela
# 51389            Canada
# 51390     United States
# 51391           Ireland
# Name: Country, Length: 51392, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States      11455
# India               5197
# United Kingdom      4395
# Germany             4143
# Canada              2233
#                    ...
# Pitcairn Island        1
# French Guyana          1
# Gabon                  1
# Monaco                 1
# Saint Helena           1
# Name: Country, Length: 201, dtype: int64

# %%
df.groupby(['Country'])

# %%
country_grp = df.groupby(['Country'])

# %%
type(country_grp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
country_grp.get_group('United States')
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 3               4  Professional non-developer who sometimes write...
# 6               7  Professional non-developer who sometimes write...
# 10             11  Professional non-developer who sometimes write...
# 15             16                             Professional developer
# ...           ...                                                ...
# 51380       51381                             Professional developer
# 51381       51382  Professional non-developer who sometimes write...
# 51384       51385                             Professional developer
# 51387       51388                             Professional developer
# 51390       51391                             Professional developer
#
#                     ProgramHobby        Country      University  \
# 0                      Yes, both  United States              No
# ...

# %%
country_grp.get_group('India')
# Out:
#        Respondent            Professional               ProgramHobby Country  \
# 26             27  Professional developer                         No   India
# 61             62  Professional developer  Yes, I program as a hobby   India
# 66             67  Professional developer                         No   India
# 94             95  Professional developer                  Yes, both   India
# 107           108  Professional developer  Yes, I program as a hobby   India
# ...           ...                     ...                        ...     ...
# 51340       51341  Professional developer  Yes, I program as a hobby   India
# 51343       51344  Professional developer  Yes, I program as a hobby   India
# 51346       51347  Professional developer                  Yes, both   India
# 51347       51348                 Student                         No   India
# 51361       51362  Professional developer  Yes, I program as a hobby   India
#
# ...

# %%
filt = df['Country'] == 'United States'
df.loc[filt]
# Out:
#        Respondent                                       Professional  \
# 0               1                                            Student
# 3               4  Professional non-developer who sometimes write...
# 6               7  Professional non-developer who sometimes write...
# 10             11  Professional non-developer who sometimes write...
# 15             16                             Professional developer
# ...           ...                                                ...
# 51380       51381                             Professional developer
# 51381       51382  Professional non-developer who sometimes write...
# 51384       51385                             Professional developer
# 51387       51388                             Professional developer
# 51390       51391                             Professional developer
#
#                     ProgramHobby        Country      University  \
# 0                      Yes, both  United States              No
# ...

# %%
df.loc[filt]['StackOverflowSatisfaction'].value_counts()
# Out:
# 8.0     2404
# 10.0    2288
# 9.0     2260
# 7.0     1211
# 6.0      396
# 5.0      216
# 4.0       58
# 3.0       41
# 2.0       25
# 1.0       15
# 0.0        8
# Name: StackOverflowSatisfaction, dtype: int64

# %%
country_grp['StackOverflowSatisfaction'].value_counts().head(10)
# Out:
# Country        StackOverflowSatisfaction
# Afghanistan    10.0                         4
#                5.0                          2
#                8.0                          2
#                6.0                          1
#                7.0                          1
# Aland Islands  1.0                          1
#                7.0                          1
#                8.0                          1
#                9.0                          1
#                10.0                         1
# Name: StackOverflowSatisfaction, dtype: int64

# %%
country_grp['StackOverflowSatisfaction'].value_counts().loc['India']
# Out:
# StackOverflowSatisfaction
# 10.0    770
# 8.0     767
# 9.0     748
# 7.0     337
# 6.0     131
# 5.0      55
# 3.0      13
# 4.0      12
# 1.0       5
# 2.0       5
# 0.0       3
# Name: StackOverflowSatisfaction, dtype: int64

# %%
country_grp['StackOverflowSatisfaction'].value_counts(normalize=True).loc['India']
# Out:
# StackOverflowSatisfaction
# 10.0    0.270555
# 8.0     0.269501
# 9.0     0.262825
# 7.0     0.118412
# 6.0     0.046030
# 5.0     0.019325
# 3.0     0.004568
# 4.0     0.004216
# 1.0     0.001757
# 2.0     0.001757
# 0.0     0.001054
# Name: StackOverflowSatisfaction, dtype: float64

# %%
country_grp['Salary'].median()
# Out:
# Country
# Afghanistan              16143.497758
# Aland Islands                     NaN
# Albania                  16129.032258
# Algeria                           NaN
# American Samoa                    NaN
#                             ...
# Virgin Islands (USA)    175000.000000
# Yemen                     1000.000000
# Zaire                     4800.000000
# Zambia                            NaN
# Zimbabwe                   700.000000
# Name: Salary, Length: 201, dtype: float64

# %%
country_grp['Salary'].median().loc['Germany']
# Out:
# 52903.2258064516

# %%
country_grp['Salary'].agg(['median','mean']).loc['Germany']
# Out:
# median    52903.225806
# mean      51616.301032
# Name: Germany, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['StackOverflowDevices'].str.contains('Desktop')
# Out:
# 26        NaN
# 61       True
# 66       True
# 94       True
# 107      True
#          ...
# 51340    True
# 51343    True
# 51346     NaN
# 51347    True
# 51361     NaN
# Name: StackOverflowDevices, Length: 5197, dtype: object

# %%
filt = df['Country'] == 'India'
df.loc[filt]['StackOverflowDevices'].str.contains('Desktop').sum()
# Out:
# 2589

# %%
country_grp['StackOverflowDevices'].apply(lambda x: x.str.contains('Desktop').sum())
# Out:
# Country
# Afghanistan              8
# Aland Islands            3
# Albania                 31
# Algeria                 17
# American Samoa           0
#                         ..
# Virgin Islands (USA)     4
# Yemen                    2
# Zaire                    2
# Zambia                   4
# Zimbabwe                10
# Name: StackOverflowDevices, Length: 201, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States      11455
# India               5197
# United Kingdom      4395
# Germany             4143
# Canada              2233
#                    ...
# Pitcairn Island        1
# French Guyana          1
# Gabon                  1
# Monaco                 1
# Saint Helena           1
# Name: Country, Length: 201, dtype: int64

# %%
country_uses_desktop = country_grp['StackOverflowDevices'].apply(lambda x: x.str.contains('Desktop').sum())
country_uses_desktop
# Out:
# Country
# Afghanistan              8
# Aland Islands            3
# Albania                 31
# Algeria                 17
# American Samoa           0
#                         ..
# Virgin Islands (USA)     4
# Yemen                    2
# Zaire                    2
# Zambia                   4
# Zimbabwe                10
# Name: StackOverflowDevices, Length: 201, dtype: int64

# %%
desktop_df = pd.concat([country_respondents, country_uses_desktop], axis='columns')
desktop_df
# Out:
#                  Country  StackOverflowDevices
# United States      11455                  8654
# India               5197                  2589
# United Kingdom      4395                  3304
# Germany             4143                  2988
# Canada              2233                  1636
# ...                  ...                   ...
# Pitcairn Island        1                     1
# French Guyana          1                     0
# Gabon                  1                     1
# Monaco                 1                     0
# Saint Helena           1                     0
#
# [201 rows x 2 columns]

# %%
desktop_df.rename(columns={'Country': 'NumberOfRespondents', 'StackOverflowDevices': 'NumberUsesDesktop'}, inplace=True)

# %%
desktop_df
# Out:
#                  NumberOfRespondents  NumberUsesDesktop
# United States                  11455               8654
# India                           5197               2589
# United Kingdom                  4395               3304
# Germany                         4143               2988
# Canada                          2233               1636
# ...                              ...                ...
# Pitcairn Island                    1                  1
# French Guyana                      1                  0
# Gabon                              1                  1
# Monaco                             1                  0
# Saint Helena                       1                  0
#
# [201 rows x 2 columns]

# %%
desktop_df['PercentUsesDesktop'] = (python_df['NumberUsesDesktop']/python_df['NumberOfRespondents']) * 100
desktop_df
# Out:
#                  NumberOfRespondents  NumberUsesDesktop  PercentUsesDesktop
# United States                  11455               8654           75.547796
# India                           5197               2589           49.817202
# United Kingdom                  4395               3304           75.176337
# Germany                         4143               2988           72.121651
# Canada                          2233               1636           73.264666
# ...                              ...                ...                 ...
# Pitcairn Island                    1                  1          100.000000
# French Guyana                      1                  0            0.000000
# Gabon                              1                  1          100.000000
# Monaco                             1                  0            0.000000
# Saint Helena                       1                  0            0.000000
#
# [201 rows x 3 columns]

# %%
desktop_df.sort_values(by='PercentUsesDesktop', ascending=False)
# Out:
#                             NumberOfRespondents  NumberUsesDesktop  \
# Cayman Islands                                2                  2
# Turkmenistan                                  1                  1
# Antigua and Barbuda                           3                  3
# Saint Vincent & Grenadines                    2                  2
# Benin                                         2                  2
# ...                                         ...                ...
# Aruba                                         2                  0
# Bhutan                                        2                  0
# Burundi                                       2                  0
# Anguilla                                      2                  0
# Saint Helena                                  1                  0
#
#                             PercentUsesDesktop
# Cayman Islands                           100.0
# Turkmenistan                             100.0
# ...

# %%
desktop_df.sort_values(by='PercentUsesDesktop', ascending=False, inplace=True)

# %%
desktop_df.head(50)
# Out:
#                                 NumberOfRespondents  NumberUsesDesktop  \
# Cayman Islands                                    2                  2
# Turkmenistan                                      1                  1
# Antigua and Barbuda                               3                  3
# Saint Vincent & Grenadines                        2                  2
# Benin                                             2                  2
# Zaire                                             2                  2
# Falkland Islands                                  1                  1
# Chad                                              1                  1
# Montserrat                                        1                  1
# S. Georgia & S. Sandwich Isls.                    1                  1
# Guam                                              1                  1
# Cape Verde                                        1                  1
# ...

# %%
desktop_df.loc['Japan']
# Out:
# NumberOfRespondents    248.000000
# NumberUsesDesktop      146.000000
# PercentUsesDesktop      58.870968
# Name: Japan, dtype: float64

# %%
type(desktop_df.loc['Japan'])
# Out:
# pandas.core.series.Series
